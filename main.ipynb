# %%
# Importações necessárias
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# Definir semente para reprodutibilidade
tf.random.set_seed(42)
np.random.seed(42)

# %%
# --- Parâmetros ---
# A InceptionResNetV2 foi pré-treinada com este tamanho:
IMAGE_SIZE = (299, 299)
BATCH_SIZE = 8  # Use um batch size pequeno devido ao número reduzido de imagens
NUM_CLASSES = 3  # Substitua pelo número real de pessoas/classes que você tem
# --- Caminhos ---
train_dir = 'dataset/treino'
validation_dir = 'dataset/validacao'

# %%
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input

# Gerador para o conjunto de treinamento com Aumento de Dados
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,       # Rotação de até 20 graus
    width_shift_range=0.2,   # Deslocamento horizontal
    height_shift_range=0.2,  # Deslocamento vertical
    shear_range=0.2,         # Cisalhamento
    zoom_range=0.2,          # Zoom aleatório
    horizontal_flip=True,    # Espelhamento horizontal (comum em faces)
    fill_mode='nearest'
)

# Gerador para o conjunto de validação (somente pré-processamento)
validation_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Criação dos geradores de fluxo de dados
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)
# Out:
# Found 15 images belonging to 3 classes.
# Found 6 images belonging to 3 classes.

# %%
# 3.1. Carregar a InceptionResNetV2 pré-treinada
# include_top=False: Remove a camada de classificação original (1000 classes do ImageNet)
# weights='imagenet': Carrega os pesos pré-treinados
base_model = InceptionResNetV2(
    weights='imagenet', 
    include_top=False, 
    input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
)

# 3.2. Congelar as camadas da base
# Isso impede que os pesos pré-treinados sejam alterados durante o treinamento
for layer in base_model.layers:
    layer.trainable = False

# 3.3. Adicionar as novas camadas de classificação (a "cabeça")
x = base_model.output
x = GlobalAveragePooling2D()(x)  # Reduz a dimensão para um vetor de características
x = Dense(1024, activation='relu')(x)  # Camada Densa com ReLU
x = Dropout(0.5)(x)  # Dropout para evitar overfitting
predictions = Dense(train_generator.num_classes, activation='softmax')(x) # Camada de Saída

# 3.4. Construir o modelo final
model = Model(inputs=base_model.input, outputs=predictions)

# 3.5. Compilar o modelo
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), # Taxa de aprendizado baixa
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Exibir o resumo do modelo (as camadas da base estarão "congeladas")
# model.summary()

# %%
# --- Treinamento ---
EPOCHS = 50 # Número pequeno de épocas para começar
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE
)
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 0.2857 - loss: 1.0473 - val_accuracy: 0.5000 - val_loss: 1.2257
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 764ms/step - accuracy: 0.2500 - loss: 1.9915 - val_accuracy: 0.5000 - val_loss: 1.1527
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 807ms/step - accuracy: 0.1429 - loss: 1.5939 - val_accuracy: 0.5000 - val_loss: 1.1337
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 786ms/step - accuracy: 0.2500 - loss: 1.4157 - val_accuracy: 0.5000 - val_loss: 1.0657
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 810ms/step - accuracy: 0.7143 - loss: 0.8225 - val_accuracy: 0.5000 - val_loss: 1.0253
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 783ms/step - accuracy: 0.5000 - loss: 1.1093 - val_accuracy: 0.5000 - val_loss: 0.9660
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 819ms/step - accuracy: 0.7143 - loss: 0.8948 - val_accuracy: 0.6667 - val_loss: 0.9359
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 816ms/step - accuracy: 0.3750 - loss: 1.1172 - val_accuracy: 0.6667 - val_loss: 0.8982
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 877ms/step - accuracy: 0.5000 - loss: 1.0427 - val_accuracy: 0.6667 - val_loss: 0.8525
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step - accuracy: 0.8571 - loss: 0.8740 - val_accuracy: 0.8333 - val_loss: 0.8159
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 881ms/step - accuracy: 0.7500 - loss: 0.6864 - val_accuracy: 0.8333 - val_loss: 0.7852
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step - accuracy: 0.4286 - loss: 1.0759 - val_accuracy: 0.8333 - val_loss: 0.7518
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 834ms/step - accuracy: 0.7143 - loss: 0.6471 - val_accuracy: 1.0000 - val_loss: 0.7234
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 782ms/step - accuracy: 0.8750 - loss: 0.6585 - val_accuracy: 1.0000 - val_loss: 0.7026
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 820ms/step - accuracy: 0.5714 - loss: 0.8780 - val_accuracy: 1.0000 - val_loss: 0.6848
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 792ms/step - accuracy: 1.0000 - loss: 0.3984 - val_accuracy: 1.0000 - val_loss: 0.6732
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 817ms/step - accuracy: 0.7143 - loss: 0.6196 - val_accuracy: 1.0000 - val_loss: 0.6635
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 776ms/step - accuracy: 0.8750 - loss: 0.5226 - val_accuracy: 1.0000 - val_loss: 0.6535
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step - accuracy: 1.0000 - loss: 0.4387 - val_accuracy: 1.0000 - val_loss: 0.6444
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 771ms/step - accuracy: 0.7143 - loss: 0.5883 - val_accuracy: 1.0000 - val_loss: 0.6300
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 806ms/step - accuracy: 1.0000 - loss: 0.3573 - val_accuracy: 1.0000 - val_loss: 0.6175
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 795ms/step - accuracy: 0.7500 - loss: 0.7017 - val_accuracy: 1.0000 - val_loss: 0.6029
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 857ms/step - accuracy: 0.7500 - loss: 0.5788 - val_accuracy: 1.0000 - val_loss: 0.5856
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 718ms/step - accuracy: 0.7143 - loss: 0.6293 - val_accuracy: 1.0000 - val_loss: 0.5725
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 875ms/step - accuracy: 1.0000 - loss: 0.4652 - val_accuracy: 1.0000 - val_loss: 0.5599
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 722ms/step - accuracy: 0.8571 - loss: 0.3479 - val_accuracy: 1.0000 - val_loss: 0.5484
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 864ms/step - accuracy: 0.8571 - loss: 0.4806 - val_accuracy: 1.0000 - val_loss: 0.5449
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 816ms/step - accuracy: 0.8750 - loss: 0.4344 - val_accuracy: 1.0000 - val_loss: 0.5395
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 828ms/step - accuracy: 0.8571 - loss: 0.4799 - val_accuracy: 1.0000 - val_loss: 0.5320
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 822ms/step - accuracy: 0.8750 - loss: 0.3222 - val_accuracy: 1.0000 - val_loss: 0.5241
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 839ms/step - accuracy: 1.0000 - loss: 0.2504 - val_accuracy: 1.0000 - val_loss: 0.5162
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 791ms/step - accuracy: 0.8750 - loss: 0.5214 - val_accuracy: 1.0000 - val_loss: 0.5075
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 826ms/step - accuracy: 0.8571 - loss: 0.4327 - val_accuracy: 1.0000 - val_loss: 0.5007
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 798ms/step - accuracy: 0.8750 - loss: 0.2560 - val_accuracy: 1.0000 - val_loss: 0.4994
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 889ms/step - accuracy: 0.8750 - loss: 0.3820 - val_accuracy: 1.0000 - val_loss: 0.5036
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step - accuracy: 1.0000 - loss: 0.2091 - val_accuracy: 0.6667 - val_loss: 0.5087
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 877ms/step - accuracy: 0.8750 - loss: 0.4019 - val_accuracy: 0.6667 - val_loss: 0.5141
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 732ms/step - accuracy: 1.0000 - loss: 0.2382 - val_accuracy: 0.6667 - val_loss: 0.5186
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 880ms/step - accuracy: 0.7500 - loss: 0.3825 - val_accuracy: 0.6667 - val_loss: 0.5227
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 746ms/step - accuracy: 0.8571 - loss: 0.4371 - val_accuracy: 0.6667 - val_loss: 0.5153
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 892ms/step - accuracy: 0.8750 - loss: 0.3150 - val_accuracy: 0.6667 - val_loss: 0.5094
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 746ms/step - accuracy: 1.0000 - loss: 0.2965 - val_accuracy: 0.6667 - val_loss: 0.5015
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 890ms/step - accuracy: 0.7500 - loss: 0.5160 - val_accuracy: 0.6667 - val_loss: 0.4925
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 718ms/step - accuracy: 1.0000 - loss: 0.1948 - val_accuracy: 0.6667 - val_loss: 0.4847
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 845ms/step - accuracy: 1.0000 - loss: 0.2313 - val_accuracy: 0.8333 - val_loss: 0.4776
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 799ms/step - accuracy: 0.8750 - loss: 0.3206 - val_accuracy: 0.8333 - val_loss: 0.4748
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 910ms/step - accuracy: 0.8750 - loss: 0.2290 - val_accuracy: 0.8333 - val_loss: 0.4729
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 760ms/step - accuracy: 1.0000 - loss: 0.2016 - val_accuracy: 0.8333 - val_loss: 0.4724
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 899ms/step - accuracy: 1.0000 - loss: 0.2379 - val_accuracy: 0.8333 - val_loss: 0.4719
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step - accuracy: 1.0000 - loss: 0.2863 - val_accuracy: 0.8333 - val_loss: 0.4718

# %%
# 5.1. Descongelar algumas camadas do modelo base
base_model.trainable = True

# Congelar as primeiras N camadas para não destruir o aprendizado inicial
# (ex: manter as primeiras 250 camadas congeladas)
for layer in base_model.layers[:250]:
    layer.trainable = False

# 5.2. Recompilar o modelo com uma taxa de aprendizado muito baixa
# É essencial usar uma taxa de aprendizado baixa para evitar estragar os pesos pré-treinados.
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# model.summary() # Verifique quais camadas estão treináveis agora

# 5.3. Continuar o treinamento (Fine-Tuning)
FINE_TUNE_EPOCHS = 10
total_epochs = EPOCHS + FINE_TUNE_EPOCHS

history_ft = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1], # Continuar de onde parou
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE
)
# Out:
# Epoch 50/60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 1.0000 - loss: 0.2088 - val_accuracy: 0.8333 - val_loss: 0.4725
# Epoch 51/60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 734ms/step - accuracy: 1.0000 - loss: 0.0943 - val_accuracy: 0.8333 - val_loss: 0.4718
# Epoch 52/60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 894ms/step - accuracy: 1.0000 - loss: 0.2138 - val_accuracy: 0.8333 - val_loss: 0.4712
# Epoch 53/60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 752ms/step - accuracy: 1.0000 - loss: 0.1982 - val_accuracy: 0.8333 - val_loss: 0.4705
# Epoch 54/60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 898ms/step - accuracy: 1.0000 - loss: 0.1773 - val_accuracy: 0.8333 - val_loss: 0.4699
# Epoch 55/60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 761ms/step - accuracy: 1.0000 - loss: 0.1106 - val_accuracy: 0.8333 - val_loss: 0.4695
# Epoch 56/60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step - accuracy: 0.8750 - loss: 0.2136 - val_accuracy: 0.8333 - val_loss: 0.4690
# Epoch 57/60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 805ms/step - accuracy: 1.0000 - loss: 0.1808 - val_accuracy: 0.8333 - val_loss: 0.4683
# Epoch 58/60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 892ms/step - accuracy: 0.8571 - loss: 0.2490 - val_accuracy: 0.8333 - val_loss: 0.4682
# Epoch 59/60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 865ms/step - accuracy: 1.0000 - loss: 0.1495 - val_accuracy: 0.8333 - val_loss: 0.4681
# Epoch 60/60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step - accuracy: 1.0000 - loss: 0.1832 - val_accuracy: 0.8333 - val_loss: 0.4681

# %%
# Salvar o modelo final
model.save('model.keras')
print("Modelo salvo com sucesso!")
# Out:
# Modelo salvo com sucesso!
